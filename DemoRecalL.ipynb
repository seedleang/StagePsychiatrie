# %% [markdown]
# # Full analysis

# %%
import moves
moves.analyseThis()
# Out:
# Enter the child's ID.
# We'll search for their files in the current repository.
# >>>>>> dpx_1
# Let's go.
#
#
# ------------------------------------------------------------------------------------------------------------------
# KING WALKING WALKING WALKING WALKING WALKING WALKING WALKING WALKING WALKING WALKING WALKING WALKING WALKING WALKI
# ------------------------------------------------------------------------------------------------------------------
#
#
#                                               📎 (ENTERING PROCEDURE) 📎
# ------------------------------------------------------------------------------------------------------------------
#
# Retrieving calibration settings, might need to ask you.
# ...Impressive! DPX_1's settings are already on fleek - all shiny and new.
#
#
#
#                                        🔮 1. Taking a look at the sensors. 🔮
# ------------------------------------------------------------------------------------------------------------------
#
# ...
